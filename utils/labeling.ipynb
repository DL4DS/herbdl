# %%
import pandas as pd
import numpy as np
import json

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Herbaria 2022

# %%
HERBARIA22_TRAIN_PATH = "/projectnb/herbdl/data/kaggle-herbaria/herbarium-2021/train_images/"
HERBARIA22_TEST_PATH = "/projectnb/herbdl/data/kaggle-herbaria/herbarium-2022/test_images/"
HERBARIA22_METADATA_TRAIN = "/projectnb/herbdl/data/kaggle-herbaria/herbarium-2022/train_metadata.json"
HERBARIA22_METADATA_TEST = "/projectnb/herbdl/data/kaggle-herbaria/herbarium-2022/test_metadata.json"

# %%
with open(HERBARIA22_METADATA_TRAIN) as f:
    train_metadata = json.load(f)

with open(HERBARIA22_METADATA_TEST) as f:
    test_metadata = json.load(f)

# %%
categories = {cat['category_id']: cat for cat in train_metadata['categories']}
images = {im['image_id']: im for im in train_metadata['images']}
institutions = {inst['institution_id']: inst for inst in train_metadata['institutions']}

# %%
train22_processed = [] # will be turned into a dataframe later. sublists are of the form <image_id>, <image_path>, <species>, <genus>, <family>, <institution>

for i in range(len(train_metadata['annotations'])):
    image = train_metadata['annotations'][i]

    image_id = image['image_id']
    image_path = images[image_id]['file_name']
    category = categories[image['category_id']]
    institution = institutions[image['institution_id']]    

    sublist = [image_id, image_path, category['species'], category['genus'], category['family'], institution['collectionCode']]
    train22_processed += [sublist]

# %%
df = pd.DataFrame(train22_processed, columns=['image_id', 'filename', 'species', 'genus', 'family', 'institution'])
df.to_csv("/projectnb/herbdl/data/kaggle-herbaria/train_2022_metadata.csv")
df.head()
# Out:
#      image_id               filename   species  genus    family institution
# 0  00000__001  000/00/00000__001.jpg  amabilis  Abies  Pinaceae           A
# 1  00000__002  000/00/00000__002.jpg  amabilis  Abies  Pinaceae           A
# 2  00000__003  000/00/00000__003.jpg  amabilis  Abies  Pinaceae           A
# 3  00000__004  000/00/00000__004.jpg  amabilis  Abies  Pinaceae           A
# 4  00000__005  000/00/00000__005.jpg  amabilis  Abies  Pinaceae           A

# %%
len(df)
# Out:
# 839772

# %% [markdown]
# #### Labeling

# %%
labeled = []
for i, row in df.iterrows():
    species = row['species']
    genus = row['genus']
    family = row['family']
    institution = row['institution']

    img_id = row['image_id']
    filename = row['filename']
    caption = f"This is an image of species {species}, in the genus {genus} of family {family}. It is part of the collection of institution {institution}."
    scientificName = family + " " + genus + " " + species

    labeled += [[img_id, filename, caption, scientificName, family, genus, species]]

kaggle22 = pd.DataFrame(labeled, columns=["image_id", "filename", "caption", "scientificName", "family", "genus", "species"])

# %%
le = LabelEncoder()
le.fit(kaggle22['scientificName'])
kaggle22['scientificNameEncoded'] = le.transform(kaggle22['scientificName'])

kaggle22.head()

# %%
train22, val22 = train_test_split(kaggle22, test_size=0.2, random_state=42)

# %%
train22.head()
# Out:
#           image_id               filename  \
# 686446  12640__012  126/40/12640__012.jpg
# 83405   01612__004  016/12/01612__004.jpg
# 155613  02962__081  029/62/02962__081.jpg
# 455876  08401__098  084/01/08401__098.jpg
# 141438  02707__054  027/07/02707__054.jpg
#
#                                                   caption  \
# 686446  This is an image of species cordovensis, in th...
# 83405   This is an image of species sophoroides, in th...
# 155613  This is an image of species whitneyi, in the g...
# 455876  This is an image of species philadelphicum, in...
# 141438  This is an image of species hoodii, in the gen...
#
#                          scientificName      family       genus  \
# 686446   Asteraceae Roldana cordovensis  Asteraceae     Roldana
# 83405   Fabaceae Astragalus sophoroides    Fabaceae  Astragalus
# 155613        Cyperaceae Carex whitneyi  Cyperaceae       Carex
# 455876  Liliaceae Lilium philadelphicum   Liliaceae      Lilium
# 141438          Cyperaceae Carex hoodii  Cyperaceae       Carex
#
#                species  scientificNameEncoded
# 686446     cordovensis                   3150
# 83405      sophoroides                   7279
# 155613        whitneyi                   6101
# 455876  philadelphicum                   9199
# 141438          hoodii                   5846

# %%
val22.head()
# Out:
#           image_id               filename  \
# 412294  07635__028  076/35/07635__028.jpg
# 363802  06751__013  067/51/06751__013.jpg
# 790220  14572__001  145/72/14572__001.jpg
# 780204  14383__110  143/83/14383__110.jpg
# 502646  09270__114  092/70/09270__114.jpg
#
#                                                   caption  \
# 412294  This is an image of species remota, in the gen...
# 363802  This is an image of species clokeyi, in the ge...
# 790220  This is an image of species variabilis, in the...
# 780204  This is an image of species buceras, in the ge...
# 502646  This is an image of species elaeagnoides, in t...
#
#                               scientificName           family       genus  \
# 412294              Malvaceae Iliamna remota        Malvaceae     Iliamna
# 363802           Polemoniaceae Gilia clokeyi    Polemoniaceae       Gilia
# 790220    Bromeliaceae Tillandsia variabilis     Bromeliaceae  Tillandsia
# 780204       Combretaceae Terminalia buceras     Combretaceae  Terminalia
# 502646  Melastomataceae Miconia elaeagnoides  Melastomataceae     Miconia
#
#              species  scientificNameEncoded
# 412294        remota                   9543
# 363802       clokeyi                  12694
# 790220    variabilis                   4603
# 780204       buceras                   5273
# 502646  elaeagnoides                   9794

# %%
train22.shape, val22.shape
# Out:
# ((671817, 8), (167955, 8))

# %%
train22.to_csv('/projectnb/herbdl/data/kaggle-herbaria/train_2022.csv')
val22.to_csv('/projectnb/herbdl/data/kaggle-herbaria/val_2022.csv')

# %%
train22.to_json('/projectnb/herbdl/data/kaggle-herbaria/train_2022.json', orient='records', lines=True)
val22.to_json('/projectnb/herbdl/data/kaggle-herbaria/val_2022.json', orient='records', lines=True)

# %% [markdown]
# ## Herbaria 2021

# %%
HERBARIA21_TRAIN_PATH = "/projectnb/herbdl/data/kaggle-herbaria/herbarium-2021/train/"
HERBARIA21_TEST_PATH = "/projectnb/herbdl/data/kaggle-herbaria/herbarium-2021/test/"
HERBARIA21_METADATA_TRAIN = "/projectnb/herbdl/data/kaggle-herbaria/herbarium-2021/train/metadata.json"
HERBARIA21_METADATA_TEST = "/projectnb/herbdl/data/kaggle-herbaria/herbarium-2021/test/metadata.json"

# %%
with open(HERBARIA21_METADATA_TRAIN) as f:
    train_metadata = json.load(f)

with open(HERBARIA21_METADATA_TEST) as f:
    test_metadata = json.load(f)

# %%
train_metadata.keys()
# Out:
# dict_keys(['annotations', 'categories', 'images', 'info', 'licenses', 'institutions'])

# %%
train_metadata['categories']
# Out:
# [{'family': 'Orchidaceae',
#   'order': 'Asparagales',
#   'name': 'Aa calceata (Rchb.f.) Schltr.',
#   'id': 0},
#  {'family': 'Orchidaceae',
#   'order': 'Asparagales',
#   'name': 'Aa matthewsii (Rchb.f.) Schltr.',
#   'id': 1},
#  {'family': 'Orchidaceae',
#   'order': 'Asparagales',
#   'name': 'Aa paleacea (Kunth) Rchb.f.',
#   'id': 2},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema abbottii (Rose & Leonard) Barneby & J.W.Grimes',
#   'id': 3},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema acreana (J.F.Macbr.) L.Rico',
#   'id': 4},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema adenophora (Ducke) Barneby & J.W.Grimes',
#   'id': 5},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema agropecuaria Barneby & J.W.Grimes',
#   'id': 6},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema alexandrae (Urb.) Barneby & J.W.Grimes',
#   'id': 7},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema auriculata (Benth.) Barneby & J.W.Grimes',
#   'id': 8},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema barbouriana (Standl.) Barneby & J.W.Grimes',
#   'id': 9},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema barbouriana var. arenaria (Ducke) Barneby & J.W.Grimes',
#   'id': 10},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema brachystachya (DC.) Barneby & J.W.Grimes',
#   'id': 11},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema callejasii Barneby & J.W.Grimes',
#   'id': 12},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema campestris (Spruce ex Benth.) Barneby & J.W.Grimes',
#   'id': 13},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema cochleata (Willd.) Barneby & J.W.Grimes',
#   'id': 14},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema cochliocarpos (Gomes) Barneby & J.W.Grimes',
#   'id': 15},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema commutata Barneby & J.W.Grimes',
#   'id': 16},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema curvicarpa (H.S.Irwin) Barneby & J.W.Grimes',
#   'id': 17},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema ferruginea (Benth.) Pittier',
#   'id': 18},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema filamentosa (Benth.) Pittier',
#   'id': 19},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema gallorum Barneby & J.W.Grimes',
#   'id': 20},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema glauca (Urb.) Barneby & J.W.Grimes',
#   'id': 21},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema idiopoda (S.F.Blake) Barneby & J.W.Grimes',
#   'id': 22},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema jupunba (Willd.) Britton & Killip',
#   'id': 23},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema jupunba var. trapezifolia (Vahl) Barneby & J.W.Grimes',
#   'id': 24},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema killipii (Britton & Rose) Barneby & J.W.Grimes',
#   'id': 25},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema laeta (Benth.) Barneby & J.W.Grimes',
#   'id': 26},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema langsdorffii (Benth.) Barneby & J.W.Grimes',
#   'id': 27},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema lehmannii (Britton & Rose ex Britton & Killip) Barneby & J.W.Grimes',
#   'id': 28},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema leucophylla (Benth.) Barneby & J.W.Grimes',
#   'id': 29},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema levelii (Cowan) Barneby & J.W.Grimes',
#   'id': 30},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema longipedunculata (H.S.Irwin) Barneby & J.W.Grimes',
#   'id': 31},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema macradenia (Pittier) Barneby & J.W.Grimes',
#   'id': 32},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema mataybifolia (Sandwith) Barneby & J.W.Grimes',
#   'id': 33},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema microcalyx (Benth.) Barneby & J.W.Grimes',
#   'id': 34},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema microcalyx var. enteroloboides Barneby & J.W.Grimes',
#   'id': 35},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema nipensis (Britton) Barneby & J.W.Grimes',
#   'id': 36},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema obovalis (A.Rich.) Barneby & J.W.Grimes',
#   'id': 37},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema oppositifolia (Urb.) Barneby & J.W.Grimes',
#   'id': 38},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema piresii Barneby & J.W.Grimes',
#   'id': 39},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema racemiflora (Donn.Sm.) Barneby & J.W.Grimes',
#   'id': 40},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema subdimidiata (Splitg.) comb.ined.',
#   'id': 41},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema turbinata (Benth.) Barneby & J.W.Grimes',
#   'id': 42},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema villifera (Ducke) Barneby & J.W.Grimes',
#   'id': 43},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema villosa Iganci & M.P.Lima',
#   'id': 44},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abarema zolleriana (Standl. & Steyerm.) Barneby & J.W.Grimes',
#   'id': 45},
#  {'family': 'Salicaceae',
#   'order': 'Malpighiales',
#   'name': 'Abatia americana (Gardner) Eichler',
#   'id': 46},
#  {'family': 'Salicaceae',
#   'order': 'Malpighiales',
#   'name': 'Abatia angeliana M.H.Alford',
#   'id': 47},
#  {'family': 'Brassicaceae',
#   'order': 'Brassicales',
#   'name': 'Abdra aprica (Beadle) Al-Shehbaz & al.',
#   'id': 48},
#  {'family': 'Linnaeaceae',
#   'order': 'Dipsacales',
#   'name': 'Abelia grandiflora_x (Rovelli ex André) Rehder',
#   'id': 49},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abelmoschus esculentus (L.) Moench',
#   'id': 50},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abelmoschus manihot (L.) Medik.',
#   'id': 51},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abelmoschus moschatus Medik.',
#   'id': 52},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies alba Mill.',
#   'id': 53},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies amabilis Douglas ex J.Forbes',
#   'id': 54},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies balsamea (L.) Mill.',
#   'id': 55},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies balsamea var. phanerolepis Fernald',
#   'id': 56},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies bracteata (D.Don) Poit.',
#   'id': 57},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies cephalonica Loudon',
#   'id': 58},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies chensiensis Tiegh.',
#   'id': 59},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies cilicica (Antoine & Kotschy) Carrière',
#   'id': 60},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies concolor (Godr.) Lindl. ex Hildebrandt',
#   'id': 61},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies fargesii Franch.',
#   'id': 62},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies firma Siebold & Zucc.',
#   'id': 63},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies fraseri (Pursh) Poir.',
#   'id': 64},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies grandis (Douglas ex D.Don) Lindl.',
#   'id': 65},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies holophylla Maxim.',
#   'id': 66},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies homolepis Siebold & Zucc.',
#   'id': 67},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies koreana E.H.Wilson',
#   'id': 68},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies lasiocarpa (Hook.) Nutt.',
#   'id': 69},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies lasiocarpa var. arizonica (Merriam) Lemmon',
#   'id': 70},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies magnifica A.MurrayBis',
#   'id': 71},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies magnifica var. shastensis Lemmon',
#   'id': 72},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies nephrolepis (Trautv. ex Maxim.) Maxim.',
#   'id': 73},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies nordmanniana (Steven) Spach',
#   'id': 74},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies numidica DeLannoy ex Carrière',
#   'id': 75},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies pinsapo Boiss.',
#   'id': 76},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies procera Rehder',
#   'id': 77},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies recurvata Mast.',
#   'id': 78},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies sachalinensis (F.Schmidt) Mast.',
#   'id': 79},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies sibirica Ledeb.',
#   'id': 80},
#  {'family': 'Pinaceae',
#   'order': 'Pinales',
#   'name': 'Abies veitchii Lindl.',
#   'id': 81},
#  {'family': 'Xyridaceae',
#   'order': 'Poales',
#   'name': 'Abolboda acaulis Maguire',
#   'id': 82},
#  {'family': 'Xyridaceae',
#   'order': 'Poales',
#   'name': 'Abolboda acicularis Idrobo & L.B.Sm.',
#   'id': 83},
#  {'family': 'Xyridaceae',
#   'order': 'Poales',
#   'name': 'Abolboda americana (Aubl.) Lanj.',
#   'id': 84},
#  {'family': 'Xyridaceae',
#   'order': 'Poales',
#   'name': 'Abolboda ciliata Maguire & Wurdack',
#   'id': 85},
#  {'family': 'Xyridaceae',
#   'order': 'Poales',
#   'name': 'Abolboda ebracteata Maguire & Wurdack',
#   'id': 86},
#  {'family': 'Xyridaceae',
#   'order': 'Poales',
#   'name': 'Abolboda engleri L.B.Sm. & Downs',
#   'id': 87},
#  {'family': 'Xyridaceae',
#   'order': 'Poales',
#   'name': 'Abolboda grandis Griseb.',
#   'id': 88},
#  {'family': 'Xyridaceae',
#   'order': 'Poales',
#   'name': 'Abolboda grandis var. rigida Malme',
#   'id': 89},
#  {'family': 'Xyridaceae',
#   'order': 'Poales',
#   'name': 'Abolboda granularis (Maguire) L.M.Campb. & Kral',
#   'id': 90},
#  {'family': 'Xyridaceae',
#   'order': 'Poales',
#   'name': 'Abolboda killipii Lasser',
#   'id': 91},
#  {'family': 'Xyridaceae',
#   'order': 'Poales',
#   'name': 'Abolboda linearifolia Maguire',
#   'id': 92},
#  {'family': 'Xyridaceae',
#   'order': 'Poales',
#   'name': 'Abolboda macrostachya Spruce ex Malme',
#   'id': 93},
#  {'family': 'Xyridaceae',
#   'order': 'Poales',
#   'name': 'Abolboda macrostachya var. robustior Steyerm.',
#   'id': 94},
#  {'family': 'Xyridaceae',
#   'order': 'Poales',
#   'name': 'Abolboda neblinae Maguire',
#   'id': 95},
#  {'family': 'Xyridaceae',
#   'order': 'Poales',
#   'name': 'Abolboda paniculata Maguire',
#   'id': 96},
#  {'family': 'Xyridaceae',
#   'order': 'Poales',
#   'name': 'Abolboda poarchon Seub.',
#   'id': 97},
#  {'family': 'Xyridaceae',
#   'order': 'Poales',
#   'name': 'Abolboda pulchella Kunth',
#   'id': 98},
#  {'family': 'Xyridaceae',
#   'order': 'Poales',
#   'name': 'Abolboda scabrida Kral',
#   'id': 99},
#  {'family': 'Xyridaceae',
#   'order': 'Poales',
#   'name': 'Abolboda sprucei Malme',
#   'id': 100},
#  {'family': 'Hymenophyllaceae',
#   'order': 'Hymenophyllales',
#   'name': 'Abrodictyum asa-grayi (Bosch) Ebihara & K.Iwats.',
#   'id': 101},
#  {'family': 'Hymenophyllaceae',
#   'order': 'Hymenophyllales',
#   'name': 'Abrodictyum brassii (Croxall) Ebihara & K.Iwats.',
#   'id': 102},
#  {'family': 'Hymenophyllaceae',
#   'order': 'Hymenophyllales',
#   'name': 'Abrodictyum caespifrons (C.Chr.) comb.ined.',
#   'id': 103},
#  {'family': 'Hymenophyllaceae',
#   'order': 'Hymenophyllales',
#   'name': 'Abrodictyum caudatum (Brack.) Ebihara & K.Iwats.',
#   'id': 104},
#  {'family': 'Hymenophyllaceae',
#   'order': 'Hymenophyllales',
#   'name': 'Abrodictyum cellulosum (Klotzsch) Ebihara & Dubuisson',
#   'id': 105},
#  {'family': 'Hymenophyllaceae',
#   'order': 'Hymenophyllales',
#   'name': 'Abrodictyum dentatum (Bosch) Ebihara & K.Iwats.',
#   'id': 106},
#  {'family': 'Hymenophyllaceae',
#   'order': 'Hymenophyllales',
#   'name': 'Abrodictyum elongatum (A.Cunn.) Ebihara & K.Iwats.',
#   'id': 107},
#  {'family': 'Hymenophyllaceae',
#   'order': 'Hymenophyllales',
#   'name': 'Abrodictyum flavofuscum (Bosch) Ebihara & K.Iwats.',
#   'id': 108},
#  {'family': 'Hymenophyllaceae',
#   'order': 'Hymenophyllales',
#   'name': 'Abrodictyum idoneum (C.V.Morton) Ebihara & K.Iwats.',
#   'id': 109},
#  {'family': 'Hymenophyllaceae',
#   'order': 'Hymenophyllales',
#   'name': 'Abrodictyum laetum (Bosch) Ebihara & K.Iwats.',
#   'id': 110},
#  {'family': 'Hymenophyllaceae',
#   'order': 'Hymenophyllales',
#   'name': 'Abrodictyum obscurum (Blume) Ebihara & K.Iwats.',
#   'id': 111},
#  {'family': 'Hymenophyllaceae',
#   'order': 'Hymenophyllales',
#   'name': 'Abrodictyum pluma (Hook.) Ebihara & K.Iwats.',
#   'id': 112},
#  {'family': 'Hymenophyllaceae',
#   'order': 'Hymenophyllales',
#   'name': 'Abrodictyum rigidum (Sw.) Ebihara & Dubuisson',
#   'id': 113},
#  {'family': 'Hymenophyllaceae',
#   'order': 'Hymenophyllales',
#   'name': 'Abrodictyum schlechteri (Brause ex Ros.) Ebihara & K.Iwats.',
#   'id': 114},
#  {'family': 'Hymenophyllaceae',
#   'order': 'Hymenophyllales',
#   'name': 'Abrodictyum sprucei (Baker) Ebihara & Dubuisson',
#   'id': 115},
#  {'family': 'Hymenophyllaceae',
#   'order': 'Hymenophyllales',
#   'name': 'Abrodictyum strictum (Menzies ex Grev. & Hook.) Ebihara & K.Iwats.',
#   'id': 116},
#  {'family': 'Hymenophyllaceae',
#   'order': 'Hymenophyllales',
#   'name': 'Abrodictyum tamarisciforme (Jacq.) Ebihara & Dubuisson',
#   'id': 117},
#  {'family': 'Hymenophyllaceae',
#   'order': 'Hymenophyllales',
#   'name': 'Abrodictyum truncatum (Copel.) comb.ined.',
#   'id': 118},
#  {'family': 'Hymenophyllaceae',
#   'order': 'Hymenophyllales',
#   'name': 'Abrodictyum windischianum (Lellinger) comb.ined.',
#   'id': 119},
#  {'family': 'Byttneriaceae',
#   'order': 'Malvales',
#   'name': 'Abroma augusta (L.) L.f.',
#   'id': 120},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Abronia alpina Brandegee',
#   'id': 121},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Abronia ameliae Lundell',
#   'id': 122},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Abronia ammophila Greene',
#   'id': 123},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Abronia angustifolia Greene',
#   'id': 124},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Abronia argillosa S.L.Welsh & Goodrich',
#   'id': 125},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Abronia bigelowii Heimerl',
#   'id': 126},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Abronia elliptica A.Nelson',
#   'id': 127},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Abronia fragrans Nutt. ex Hook.',
#   'id': 128},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Abronia latifolia Eschsch.',
#   'id': 129},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Abronia macrocarpa L.A.Galloway',
#   'id': 130},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Abronia maritima Nutt. ex S.Watson',
#   'id': 131},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Abronia mellifera Douglas ex Hook.',
#   'id': 132},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Abronia minor_x Standl.',
#   'id': 133},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Abronia nana S.Watson',
#   'id': 134},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Abronia pogonantha Heimerl',
#   'id': 135},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Abronia turbinata Torr. ex S.Watson',
#   'id': 136},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Abronia umbellata Lam.',
#   'id': 137},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Abronia villosa S.Watson',
#   'id': 138},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Abronia villosa var. aurita (Abrams) Jeps.',
#   'id': 139},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Abrotanella nivigena (F.Muell.) F.Muell. ex Benth.',
#   'id': 140},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abrus fruticulosus Wight & Arn.',
#   'id': 141},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abrus precatorius L.',
#   'id': 142},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Abrus precatorius subsp. africanus Verdc.',
#   'id': 143},
#  {'family': 'Menispermaceae',
#   'order': 'Ranunculales',
#   'name': 'Abuta barbata Miers',
#   'id': 144},
#  {'family': 'Menispermaceae',
#   'order': 'Ranunculales',
#   'name': 'Abuta brevifolia Krukoff & Moldenke',
#   'id': 145},
#  {'family': 'Menispermaceae',
#   'order': 'Ranunculales',
#   'name': 'Abuta candollei Triana & Planch.',
#   'id': 146},
#  {'family': 'Menispermaceae',
#   'order': 'Ranunculales',
#   'name': 'Abuta convexa (Vell.) Diels',
#   'id': 147},
#  {'family': 'Menispermaceae',
#   'order': 'Ranunculales',
#   'name': 'Abuta grandifolia (Mart.) Sandwith',
#   'id': 148},
#  {'family': 'Menispermaceae',
#   'order': 'Ranunculales',
#   'name': 'Abuta grisebachii Triana & Planch.',
#   'id': 149},
#  {'family': 'Menispermaceae',
#   'order': 'Ranunculales',
#   'name': 'Abuta imene (Mart.) Eichler',
#   'id': 150},
#  {'family': 'Menispermaceae',
#   'order': 'Ranunculales',
#   'name': 'Abuta mycetandra Krukoff & Barneby',
#   'id': 151},
#  {'family': 'Menispermaceae',
#   'order': 'Ranunculales',
#   'name': 'Abuta pahni (Mart.) Krukoff & Barneby',
#   'id': 152},
#  {'family': 'Menispermaceae',
#   'order': 'Ranunculales',
#   'name': 'Abuta panurensis Eichler',
#   'id': 153},
#  {'family': 'Menispermaceae',
#   'order': 'Ranunculales',
#   'name': 'Abuta rufescens Aubl.',
#   'id': 154},
#  {'family': 'Menispermaceae',
#   'order': 'Ranunculales',
#   'name': 'Abuta sandwithiana Krukoff & Barneby',
#   'id': 155},
#  {'family': 'Menispermaceae',
#   'order': 'Ranunculales',
#   'name': 'Abuta velutina Gleason',
#   'id': 156},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon abutiloides (Jacq.) Garcke ex Hochr.',
#   'id': 157},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon auritum (Wall. ex Link) Sweet',
#   'id': 158},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon berlandieri A.Gray',
#   'id': 159},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon bivalve (Cav.) Dorr',
#   'id': 160},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon buchii Urb.',
#   'id': 161},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon californicum Benth.',
#   'id': 162},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon densiflorum (Hook. & Arn.) Walp.',
#   'id': 163},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon eremitopetalum Caum',
#   'id': 164},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon fruticosum Guill. & Perr.',
#   'id': 165},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon giganteum (Jacq.) Sweet',
#   'id': 166},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon grandifolium (Willd.) Sweet',
#   'id': 167},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon haitiense Urb.',
#   'id': 168},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon hirtum (Lam.) Sweet',
#   'id': 169},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon hulseanum (Torr. & A.Gray) Torr. ex A.Gray',
#   'id': 170},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon hypoleucum A.Gray',
#   'id': 171},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon ibarrense Kunth',
#   'id': 172},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon incanum (Link) Sweet',
#   'id': 173},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon inclusum Urb.',
#   'id': 174},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon indicum (L.) Sweet',
#   'id': 175},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon indicum subsp. albescens (Miq.) Borss.Waalk.',
#   'id': 176},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon leonardii Urb.',
#   'id': 177},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon malacum S.Watson',
#   'id': 178},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon menziesii Seem.',
#   'id': 179},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon mollicomum (Willd.) Sweet',
#   'id': 180},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon mollissimum (Cav.) Sweet',
#   'id': 181},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon oxycarpum (F.Muell.) Benth.',
#   'id': 182},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon palmeri A.Gray',
#   'id': 183},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon parishii S.Watson',
#   'id': 184},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon parvulum A.Gray',
#   'id': 185},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon pedunculare Kunth',
#   'id': 186},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon peltatum K.Schum.',
#   'id': 187},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon permolle (Willd.) Sweet',
#   'id': 188},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon ramiflorum A.St.-Hil.',
#   'id': 189},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon sachetianum Fosberg',
#   'id': 190},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon sandwicense (O.Deg.) Christoph.',
#   'id': 191},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon simulans Rose',
#   'id': 192},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon theophrasti Medik.',
#   'id': 193},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon trisulcatum (Jacq.) Urb.',
#   'id': 194},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon umbelliflorum A.St.-Hil.',
#   'id': 195},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon viscosum (L.) Dorr',
#   'id': 196},
#  {'family': 'Malvaceae',
#   'order': 'Malvales',
#   'name': 'Abutilon wrightii A.Gray',
#   'id': 197},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia acinacea Lindl.',
#   'id': 198},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia acradenia F.Muell.',
#   'id': 199},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia adsurgens Maiden & Blakely',
#   'id': 200},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia adunca A.Cunn. ex G.Don',
#   'id': 201},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia alata R.Br.',
#   'id': 202},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia alleniana Maiden',
#   'id': 203},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia amblygona A.Cunn. ex Benth.',
#   'id': 204},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia ammophila Pedley',
#   'id': 205},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia amyctica R.S.Cowan & Maslin',
#   'id': 206},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia ancistrocarpa Maiden & Blakely',
#   'id': 207},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia aneura F.Muell. ex Benth.',
#   'id': 208},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia aneura var. major Pedley',
#   'id': 209},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia aneura var. tenuis Pedley',
#   'id': 210},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia angusta Maiden & Blakely',
#   'id': 211},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia aprepta Pedley',
#   'id': 212},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia argentina Pedley',
#   'id': 213},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia argyraea Tindale',
#   'id': 214},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia argyrodendron Domin',
#   'id': 215},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia argyrotricha Pedley',
#   'id': 216},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia armillata (Pedley) Pedley',
#   'id': 217},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia asperulacea F.Muell.',
#   'id': 218},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia attenuata Maiden & Blakely',
#   'id': 219},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia aulacocarpa A.Cunn. ex Benth.',
#   'id': 220},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia auriculiformis A.Cunn. ex Benth.',
#   'id': 221},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia baeuerlenii Maiden & R.T.Baker',
#   'id': 222},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia baileyana F.Muell.',
#   'id': 223},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia bakeri Maiden',
#   'id': 224},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia bancroftiorum Maiden',
#   'id': 225},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia barakulensis Pedley',
#   'id': 226},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia baueri Benth.',
#   'id': 227},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia betchei Maiden & Blakely',
#   'id': 228},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia binervata DC.',
#   'id': 229},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia binervia (J.C.Wendl.) J.F.Macbr.',
#   'id': 230},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia bivenosa DC.',
#   'id': 231},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia blakei Pedley',
#   'id': 232},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia blakei subsp. diphylla (Tindale) Pedley',
#   'id': 233},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia brachystachya Benth.',
#   'id': 234},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia brassii Pedley',
#   'id': 235},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia brownii (Poir.) Steud.',
#   'id': 236},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia brunioides A.Cunn. ex G.Don',
#   'id': 237},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia burbidgeae Pedley',
#   'id': 238},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia burdekensis Pedley',
#   'id': 239},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia burrana Pedley',
#   'id': 240},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia burrowii Maiden',
#   'id': 241},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia buxifolia A.Cunn.',
#   'id': 242},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia buxifolia subsp. pubiflora Pedley',
#   'id': 243},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia calamifolia Sweet ex Lindl.',
#   'id': 244},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia calcicola Forde & Ising',
#   'id': 245},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia calligera (Pedley) Pedley',
#   'id': 246},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia calyculata A.Cunn. ex Benth.',
#   'id': 247},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia cambagei F.Muell. ex R.T.Baker',
#   'id': 248},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia cana Maiden',
#   'id': 249},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia caroleae Pedley',
#   'id': 250},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia catenulata C.T.White',
#   'id': 251},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia celsa Tindale',
#   'id': 252},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia chinchilensis Tindale',
#   'id': 253},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia chippendalei Pedley',
#   'id': 254},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia chisholmii Bailey',
#   'id': 255},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia cincinnata F.Muell.',
#   'id': 256},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia citriodora Kodela & Maslin',
#   'id': 257},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia cochlearis (Labill.) H.L.Wendl.',
#   'id': 258},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia coleae Maslin & L.A.J.Thomson',
#   'id': 259},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia complanata A.Cunn. ex Benth.',
#   'id': 260},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia concurrens Pedley',
#   'id': 261},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia conferta A.Cunn. ex Benth.',
#   'id': 262},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia confusa Merr.',
#   'id': 263},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia conjunctifolia F.Muell.',
#   'id': 264},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia cowleana Tate',
#   'id': 265},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia crassa Pedley',
#   'id': 266},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia crassa subsp. longicoma Pedley',
#   'id': 267},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia crassicarpa A.Cunn. ex Benth.',
#   'id': 268},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia cretata Pedley',
#   'id': 269},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia crombiei C.T.White',
#   'id': 270},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia cultriformis A.Cunn. ex G.Don',
#   'id': 271},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia cupularis Domin',
#   'id': 272},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia curranii Maiden',
#   'id': 273},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia dealbata Link',
#   'id': 274},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia deanei (R.T.Baker) M.B.Welch & al.',
#   'id': 275},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia debilis Tindale',
#   'id': 276},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia decora Rchb.f.',
#   'id': 277},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia decurrens Willd.',
#   'id': 278},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia dictyophleba F.Muell.',
#   'id': 279},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia dietrichiana F.Muell.',
#   'id': 280},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia difficilis Maiden',
#   'id': 281},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia dimidiata Benth.',
#   'id': 282},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia disparrima M.W.McDonald & Maslin',
#   'id': 283},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia disparrima subsp. calidestris M.W.McDonald & Maslin',
#   'id': 284},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia drepanocarpa subsp. latifolia Pedley',
#   'id': 285},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia elachantha Maslin & M.W.McDonald',
#   'id': 286},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia elata A.Cunn. ex Benth.',
#   'id': 287},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia elongata Sieber ex DC.',
#   'id': 288},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia ensifolia Pedley',
#   'id': 289},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia eremophiloides Pedley & P.I.Forst.',
#   'id': 290},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia everistii Pedley',
#   'id': 291},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia excelsa Benth.',
#   'id': 292},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia excelsa subsp. angusta Pedley',
#   'id': 293},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia extensa Lindl.',
#   'id': 294},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia falcata Willd.',
#   'id': 295},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia falciformis DC.',
#   'id': 296},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia fasciculifera F.Muell. ex Benth.',
#   'id': 297},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia faucium Pedley',
#   'id': 298},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia filicifolia Cheel & M.B.Welch',
#   'id': 299},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia fimbriata A.Cunn. ex G.Don',
#   'id': 300},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia flavescens A.Cunn. ex Benth.',
#   'id': 301},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia fleckeri Pedley',
#   'id': 302},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia flexifolia Benth.',
#   'id': 303},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia floribunda (Vent.) Willd.',
#   'id': 304},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia fodinalis Pedley',
#   'id': 305},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia galioides Benth.',
#   'id': 306},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia georginae F.M.Bailey',
#   'id': 307},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia gittinsii Pedley',
#   'id': 308},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia glaucocarpa Maiden & Blakely',
#   'id': 309},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia gnidium Benth.',
#   'id': 310},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia gonoclada F.Muell.',
#   'id': 311},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia grandifolia Pedley',
#   'id': 312},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia granitica Maiden',
#   'id': 313},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia guymeri Tindale',
#   'id': 314},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia hakeoides A.Cunn. ex Benth.',
#   'id': 315},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia hammondii Maiden',
#   'id': 316},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia handonis Pedley',
#   'id': 317},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia harpophylla F.Muell. ex Benth.',
#   'id': 318},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia hemignosta F.Muell.',
#   'id': 319},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia hemsleyi Maiden',
#   'id': 320},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia hilliana Maiden',
#   'id': 321},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia hispidula (Sm.) Willd.',
#   'id': 322},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia hockingsii Pedley',
#   'id': 323},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia holosericea A.Cunn. ex G.Don',
#   'id': 324},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia holotricha Pedley',
#   'id': 325},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia homaloclada F.Muell.',
#   'id': 326},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia homalophylla A.Cunn. ex Benth.',
#   'id': 327},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia howittei F.Muell.',
#   'id': 328},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia hubbardiana Pedley',
#   'id': 329},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia humifusa A.Cunn. ex Benth.',
#   'id': 330},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia hyaloneura Pedley',
#   'id': 331},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia hylonoma Pedley',
#   'id': 332},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia implexa Benth.',
#   'id': 333},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia irrorata Sieber ex Spreng.',
#   'id': 334},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia islana Pedley',
#   'id': 335},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia ixioides Pedley',
#   'id': 336},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia ixiophylla Benth.',
#   'id': 337},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia jackesiana Pedley',
#   'id': 338},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia johannis Pedley',
#   'id': 339},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia johnsonii Pedley',
#   'id': 340},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia jucunda Maiden & Blakely',
#   'id': 341},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia julifera Benth.',
#   'id': 342},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia julifera subsp. curvinervia (Maiden) Pedley',
#   'id': 343},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia julifera subsp. gilbertensis Pedley',
#   'id': 344},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia juncifolia Benth.',
#   'id': 345},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia kempeana F.Muell.',
#   'id': 346},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia koa A.Gray',
#   'id': 347},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia koaia Hillebr.',
#   'id': 348},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia laccata Pedley',
#   'id': 349},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia lamprocarpa O.Schwarz',
#   'id': 350},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia latifolia Benth.',
#   'id': 351},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia latisepala Pedley',
#   'id': 352},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia lauta Pedley',
#   'id': 353},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia lazaridis Pedley',
#   'id': 354},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia legnota Pedley',
#   'id': 355},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia leichhardtii Benth.',
#   'id': 356},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia leiocalyx (Domin) Pedley',
#   'id': 357},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia leiocalyx subsp. herveyensis Pedley',
#   'id': 358},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia leprosa DC.',
#   'id': 359},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia leptocarpa A.Cunn. ex Benth.',
#   'id': 360},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia leptoloba Pedley',
#   'id': 361},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia leptostachya Benth.',
#   'id': 362},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia leucoclada subsp. argentifolia Tindale',
#   'id': 363},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia ligulata A.Cunn. ex Benth.',
#   'id': 364},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia limbata F.Muell.',
#   'id': 365},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia lineata A.Cunn. ex G.Don',
#   'id': 366},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia linifolia (Vent.) Willd.',
#   'id': 367},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia longifolia (Andrews) Willd.',
#   'id': 368},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia longifolia subsp. sophorae (Labill.) Court',
#   'id': 369},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia longispicata Benth.',
#   'id': 370},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia longissima H.L.Wendl.',
#   'id': 371},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia loroloba Tindale',
#   'id': 372},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia lysiphloia F.Muell.',
#   'id': 373},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia macradenia Benth.',
#   'id': 374},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia maidenii F.Muell.',
#   'id': 375},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia maitlandii F.Muell.',
#   'id': 376},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia mangium Willd.',
#   'id': 377},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia maranoensis Pedley',
#   'id': 378},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia mearnsii DeWild.',
#   'id': 379},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia megalantha F.Muell.',
#   'id': 380},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia meiosperma (Pedley) Pedley',
#   'id': 381},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia melanoxylon R.Br.',
#   'id': 382},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia melleodora Pedley',
#   'id': 383},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia melvillei Pedley',
#   'id': 384},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia microcybe Pedley',
#   'id': 385},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia microsperma Pedley',
#   'id': 386},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia midgleyi M.W.McDonald & Maslin',
#   'id': 387},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia minyura Randell',
#   'id': 388},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia montana Benth.',
#   'id': 389},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia monticola J.M.Black',
#   'id': 390},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia muelleriana Maiden & R.T.Baker',
#   'id': 391},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia multisiliqua (Benth.) Maconochie',
#   'id': 392},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia murrayana F.Muell. ex Benth.',
#   'id': 393},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia myrtifolia (Sm.) Willd.',
#   'id': 394},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia neobrachycarpa I.M.Turner',
#   'id': 395},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia neovernicosa Isely',
#   'id': 396},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia neriifolia A.Cunn. ex Benth.',
#   'id': 397},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia nesophila Pedley',
#   'id': 398},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia neurocarpa Hook.',
#   'id': 399},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia nuperrima Baker.f.',
#   'id': 400},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia obtusifolia A.Cunn.',
#   'id': 401},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia oraria F.Muell.',
#   'id': 402},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia orites Pedley',
#   'id': 403},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia orthocarpa F.Muell.',
#   'id': 404},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia oshanesii F.Muell. & Maiden',
#   'id': 405},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia oswaldii F.Muell.',
#   'id': 406},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia paradoxa DC.',
#   'id': 407},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia paraneura Randell',
#   'id': 408},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia parramattensis Tindale',
#   'id': 409},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia parvifolia F.Muell.',
#   'id': 410},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia pedleyi Tindale & Kodela',
#   'id': 411},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia pendula A.Cunn. ex G.Don',
#   'id': 412},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia penninervis DC.',
#   'id': 413},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia penninervis var. longiracemosa Domin',
#   'id': 414},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia petraea Pedley',
#   'id': 415},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia peuce F.Muell.',
#   'id': 416},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia phlebocarpa F.Muell.',
#   'id': 417},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia platycarpa F.Muell.',
#   'id': 418},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia plectocarpa subsp. tanumbirinensis (Maiden) Pedley',
#   'id': 419},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia podalyriaefolia A.Cunn. ex G.Don',
#   'id': 420},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia polifolia Pedley',
#   'id': 421},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia polyadenia (Pedley) Pedley',
#   'id': 422},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia polybotrya Benth.',
#   'id': 423},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia polystachya A.Cunn. ex Benth.',
#   'id': 424},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia porcata P.I.Forst.',
#   'id': 425},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia pravissima F.Muell. ex Benth.',
#   'id': 426},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia pruinosa Benth.',
#   'id': 427},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia pubescens (Vent.) R.Br.',
#   'id': 428},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia pubifolia Pedley',
#   'id': 429},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia pubirhachis Pedley',
#   'id': 430},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia pulchella R.Br.',
#   'id': 431},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia purpureopetala F.M.Bailey',
#   'id': 432},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia pustula Maiden & Blakely',
#   'id': 433},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia pycnantha Benth.',
#   'id': 434},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia pycnocephala Maslin',
#   'id': 435},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia quadrilateralis DC.',
#   'id': 436},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia racospermoides Pedley',
#   'id': 437},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia ramiflora Domin',
#   'id': 438},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia ramulosa W.Fitzg.',
#   'id': 439},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia resinicostata Pedley',
#   'id': 440},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia retinodes Schltdl.',
#   'id': 441},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia retivenea F.Muell.',
#   'id': 442},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia rhodoxylon Maiden',
#   'id': 443},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia riceana Hensl.',
#   'id': 444},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia rigens A.Cunn. ex G.Don',
#   'id': 445},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia rothii F.M.Bailey',
#   'id': 446},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia rubida A.Cunn.',
#   'id': 447},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acacia rubricaulis Pedley',
#   'id': 448},
# ...
#   'name': 'Aciphylla simplex Petrie',
#   'id': 861},
#  {'family': 'Apiaceae',
#   'order': 'Apiales',
#   'name': 'Aciphylla spedenii Cheeseman',
#   'id': 862},
#  {'family': 'Apiaceae',
#   'order': 'Apiales',
#   'name': 'Aciphylla squarrosa J.R.Forst. & G.Forst.',
#   'id': 863},
#  {'family': 'Apiaceae',
#   'order': 'Apiales',
#   'name': 'Aciphylla subflabellata W.R.B.Oliv.',
#   'id': 864},
#  {'family': 'Apiaceae',
#   'order': 'Apiales',
#   'name': 'Aciphylla traillii Kirk',
#   'id': 865},
#  {'family': 'Apiaceae',
#   'order': 'Apiales',
#   'name': 'Aciphylla traversii (F.Muell.) Hook.f.',
#   'id': 866},
#  {'family': 'Melastomataceae',
#   'order': 'Myrtales',
#   'name': 'Acisanthera alsinefolia (DC.) Triana',
#   'id': 867},
#  {'family': 'Melastomataceae',
#   'order': 'Myrtales',
#   'name': 'Acisanthera ayangannae comb.ined.',
#   'id': 868},
#  {'family': 'Melastomataceae',
#   'order': 'Myrtales',
#   'name': 'Acisanthera divaricata Cogn.',
#   'id': 869},
#  {'family': 'Melastomataceae',
#   'order': 'Myrtales',
#   'name': 'Acisanthera paraguayensis (Hook.f.) Cogn.',
#   'id': 870},
#  {'family': 'Melastomataceae',
#   'order': 'Myrtales',
#   'name': 'Acisanthera quadrata Pers.',
#   'id': 871},
#  {'family': 'Melastomataceae',
#   'order': 'Myrtales',
#   'name': 'Acisanthera uniflora (Vahl) Gleason',
#   'id': 872},
#  {'family': 'Melastomataceae',
#   'order': 'Myrtales',
#   'name': 'Acisanthera variabilis (Mart. ex DC.) Triana',
#   'id': 873},
#  {'family': 'Cunoniaceae',
#   'order': 'Oxalidales',
#   'name': 'Ackama rosifolia A.Cunn.',
#   'id': 874},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Acleisanthes angustifolia (Torr.) R.A.Levin',
#   'id': 875},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Acleisanthes chenopodioides (A.Gray) R.A.Levin',
#   'id': 876},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Acleisanthes crassifolia A.Gray',
#   'id': 877},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Acleisanthes diffusa (A.Gray) R.A.Levin',
#   'id': 878},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Acleisanthes lanceolata (Wooton) R.A.Levin',
#   'id': 879},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Acleisanthes longiflora A.Gray',
#   'id': 880},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Acleisanthes nevadensis (Standl.) B.L.Turner',
#   'id': 881},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Acleisanthes obtusa (Choisy) Standl.',
#   'id': 882},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Acleisanthes parvifolia (Torr.) R.A.Levin',
#   'id': 883},
#  {'family': 'Nyctaginaceae',
#   'order': 'Caryophyllales',
#   'name': 'Acleisanthes wrightii (A.Gray) Benth. & Hook.f. ex Hemsl.',
#   'id': 884},
#  {'family': 'Malpighiaceae',
#   'order': 'Malpighiales',
#   'name': 'Acmanthera latifolia (A.Juss.) Griseb.',
#   'id': 885},
#  {'family': 'Malpighiaceae',
#   'order': 'Malpighiales',
#   'name': 'Acmanthera longifolia Nied.',
#   'id': 886},
#  {'family': 'Malpighiaceae',
#   'order': 'Malpighiales',
#   'name': 'Acmanthera parviflora W.R.Anderson',
#   'id': 887},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': "Acmella alba (L'Hér.) R.K.Jansen",
#   'id': 888},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acmella bellidioides (Sm.) R.K.Jansen',
#   'id': 889},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acmella brachyglossa Cass.',
#   'id': 890},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acmella ciliata (Kunth) Cass.',
#   'id': 891},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acmella grandiflora (Turcz.) R.K.Jansen',
#   'id': 892},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acmella iodiscaea (A.H.Moore) R.K.Jansen',
#   'id': 893},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acmella leptophylla (DC.) R.K.Jansen',
#   'id': 894},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acmella oleracea (L.) R.K.Jansen',
#   'id': 895},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acmella pilosa R.K.Jansen',
#   'id': 896},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acmella pusilla (Hook. & Arn.) R.K.Jansen',
#   'id': 897},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acmella radicans (Jacq.) R.K.Jansen',
#   'id': 898},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acmella radicans var. debilis (Kunth) R.K.Jansen',
#   'id': 899},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acmella repens (Walter) Rich. ex Pers.',
#   'id': 900},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acmella uliginosa (Sw.) Cass.',
#   'id': 901},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon americanus (Nutt.) Rydb.',
#   'id': 902},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon argophyllus (A.Gray) Brouillet',
#   'id': 903},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon argyraeus (Greene) Brouillet',
#   'id': 904},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon brachycarpus (Benth.) D.D.Sokoloff',
#   'id': 905},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon cytisoides (Benth.) Brouillet',
#   'id': 906},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon denticulatus (Drew) D.D.Sokoloff',
#   'id': 907},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon glabrus (Vogel) Brouillet',
#   'id': 908},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon grandiflorus (Benth.) Brouillet',
#   'id': 909},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon greenei (Wooton & Standl.) Brouillet',
#   'id': 910},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon heermannii (Durand & Hilg.) Brouillet',
#   'id': 911},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon junceus (Benth.) Brouillet',
#   'id': 912},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon maritimus (Nutt.) D.D.Sokoloff',
#   'id': 913},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon mearnsii (Britton) Brouillet',
#   'id': 914},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon micranthus (Torr. & A.Gray) Brouillet',
#   'id': 915},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon nevadensis (S.Watson) Brouillet',
#   'id': 916},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon oroboides (Kunth) Brouillet',
#   'id': 917},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon parviflorus (Benth.) D.D.Sokoloff',
#   'id': 918},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon prostratus (L.) Brouillet',
#   'id': 919},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon rigidus (Benth.) Brouillet',
#   'id': 920},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon strigosus (Nutt.) Brouillet',
#   'id': 921},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon subpinnatus (Lag.) D.D.Sokoloff',
#   'id': 922},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon utahensis (Ottley) Brouillet',
#   'id': 923},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon wrangelianus (Fisch. & C.A.Mey.) D.D.Sokoloff',
#   'id': 924},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acmispon wrightii (A.Gray) Brouillet',
#   'id': 925},
#  {'family': 'Podocarpaceae',
#   'order': 'Pinales',
#   'name': 'Acmopyle pancheri (Brongn. & Gris) Pilg.',
#   'id': 926},
#  {'family': 'Podocarpaceae',
#   'order': 'Pinales',
#   'name': 'Acmopyle sahniana J.Buchholz & N.E.Gray',
#   'id': 927},
#  {'family': 'Solanaceae',
#   'order': 'Solanales',
#   'name': 'Acnistus arborescens (L.) Schltdl.',
#   'id': 928},
#  {'family': 'Arecaceae',
#   'order': 'Arecales',
#   'name': 'Acoelorrhaphe wrightii (Griseb. & H.Wendl.) H.Wendl. ex Becc.',
#   'id': 929},
#  {'family': 'Apocynaceae',
#   'order': 'Gentianales',
#   'name': 'Acokanthera oblongifolia (Hochst.) Benth. & Hook.f. ex B.D.Jacks.',
#   'id': 930},
#  {'family': 'Apocynaceae',
#   'order': 'Gentianales',
#   'name': 'Acokanthera oppositifolia (Lam.) Codd',
#   'id': 931},
#  {'family': 'Ranunculaceae',
#   'order': 'Ranunculales',
#   'name': 'Aconitum carmichaeli Debeaux',
#   'id': 932},
#  {'family': 'Ranunculaceae',
#   'order': 'Ranunculales',
#   'name': 'Aconitum columbianum Nutt.',
#   'id': 933},
#  {'family': 'Ranunculaceae',
#   'order': 'Ranunculales',
#   'name': 'Aconitum columbianum subsp. viviparum (Greene) Brink',
#   'id': 934},
#  {'family': 'Ranunculaceae',
#   'order': 'Ranunculales',
#   'name': 'Aconitum delphinifolium DC.',
#   'id': 935},
#  {'family': 'Ranunculaceae',
#   'order': 'Ranunculales',
#   'name': 'Aconitum lycoctonum L.',
#   'id': 936},
#  {'family': 'Ranunculaceae',
#   'order': 'Ranunculales',
#   'name': 'Aconitum maximum Pall. ex DC.',
#   'id': 937},
#  {'family': 'Ranunculaceae',
#   'order': 'Ranunculales',
#   'name': 'Aconitum noveboracense A.Gray ex Coville',
#   'id': 938},
#  {'family': 'Ranunculaceae',
#   'order': 'Ranunculales',
#   'name': 'Aconitum reclinatum A.Gray',
#   'id': 939},
#  {'family': 'Ranunculaceae',
#   'order': 'Ranunculales',
#   'name': 'Aconitum uncinatum L.',
#   'id': 940},
#  {'family': 'Ranunculaceae',
#   'order': 'Ranunculales',
#   'name': 'Aconitum vaccarum Rydb.',
#   'id': 941},
#  {'family': 'Acoraceae',
#   'order': 'Acorales',
#   'name': 'Acorus calamus L.',
#   'id': 942},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acosmium cardenasii H.S.Irwin & Arroyo',
#   'id': 943},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acosmium diffusissimum (Mohlenbr.) Yakovlev',
#   'id': 944},
#  {'family': 'Fabaceae',
#   'order': 'Fabales',
#   'name': 'Acosmium lentiscifolium Schott',
#   'id': 945},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acourtia fruticosa (LaLlave & Lex.) B.L.Turner',
#   'id': 946},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acourtia microcephala DC.',
#   'id': 947},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acourtia nana (A.Gray) Reveal & R.M.King',
#   'id': 948},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acourtia runcinata (Lag. ex D.Don) B.L.Turner',
#   'id': 949},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acourtia thurberi (A.Gray) Reveal & R.M.King',
#   'id': 950},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acourtia wrightii (A.Gray) Reveal & R.M.King',
#   'id': 951},
#  {'family': 'Poaceae',
#   'order': 'Poales',
#   'name': 'Acrachne racemosa (B.Heyne ex Roem. & Schult.) Ohwi',
#   'id': 952},
#  {'family': 'Orchidaceae',
#   'order': 'Asparagales',
#   'name': 'Acriopsis liliifolia (J.Koenig) Seidenf.',
#   'id': 953},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acritopappus confertus (Gardner) R.M.King & H.Rob.',
#   'id': 954},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acritopappus connatifolius (Soar.Nunes) R.M.King & H.Rob.',
#   'id': 955},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acritopappus hagei R.M.King & H.Rob.',
#   'id': 956},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acritopappus heterolepis (Baker) R.M.King & H.Rob.',
#   'id': 957},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acritopappus irwinii R.M.King & H.Rob.',
#   'id': 958},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acritopappus longifolius (Gardner) R.M.King & H.Rob.',
#   'id': 959},
#  {'family': 'Asteraceae',
#   'order': 'Asterales',
#   'name': 'Acritopappus micropappus (Baker) R.M.King & H.Rob.',
#   'id': 960},
#  {'family': 'Poaceae',
#   'order': 'Poales',
#   'name': 'Acroceras excavatum (Henrard) Zuloaga & Morrone',
#   'id': 961},
#  {'family': 'Poaceae',
#   'order': 'Poales',
#   'name': 'Acroceras fluminense (Hack.) Zuloaga & Morrone',
#   'id': 962},
#  {'family': 'Poaceae',
#   'order': 'Poales',
#   'name': 'Acroceras zizanioides (Kunth) Dandy',
#   'id': 963},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia brassii T.G.Hartley',
#   'id': 964},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia carrii T.G.Hartley',
#   'id': 965},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia crassipetala T.G.Hartley',
#   'id': 966},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia emarginata Lauterb.',
#   'id': 967},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia foveata T.G.Hartley',
#   'id': 968},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia kaindiensis T.G.Hartley',
#   'id': 969},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia laevis J.R.Forst. & G.Forst.',
#   'id': 970},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia ledermannii Lauterb.',
#   'id': 971},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia littoralis T.G.Hartley & J.B.Williams',
#   'id': 972},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia montana T.G.Hartley',
#   'id': 973},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia murina Ridl.',
#   'id': 974},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia normanbiensis T.G.Hartley',
#   'id': 975},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia pedunculata (L.) Miq.',
#   'id': 976},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia pullei Lauterb.',
#   'id': 977},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia reticulata Lauterb.',
#   'id': 978},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia rugosa T.G.Hartley',
#   'id': 979},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia smithii T.G.Hartley',
#   'id': 980},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia trifoliolata Zoll. & Moritzi',
#   'id': 981},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia trifoliolata var. ampla T.G.Hartley',
#   'id': 982},
#  {'family': 'Rutaceae',
#   'order': 'Sapindales',
#   'name': 'Acronychia trifoliolata var. microcarpa T.G.Hartley',
#   'id': 983},
#  {'family': 'Polypodiaceae',
#   'order': 'Polypodiales',
#   'name': 'Acrosorus reineckei (Christ) Copel.',
#   'id': 984},
#  {'family': 'Polypodiaceae',
#   'order': 'Polypodiales',
#   'name': 'Acrosorus schlechteri Christ',
#   'id': 985},
#  {'family': 'Pteridaceae',
#   'order': 'Polypodiales',
#   'name': 'Acrostichum aureum L.',
#   'id': 986},
#  {'family': 'Pteridaceae',
#   'order': 'Polypodiales',
#   'name': 'Acrostichum danaeifolium Langsd. & Fisch.',
#   'id': 987},
#  {'family': 'Pteridaceae',
#   'order': 'Polypodiales',
#   'name': 'Acrostichum speciosum Willd.',
#   'id': 988},
#  {'family': 'Rubiaceae',
#   'order': 'Gentianales',
#   'name': 'Acrosynanthus jamaicensis Howard & Proctor',
#   'id': 989},
#  {'family': 'Rubiaceae',
#   'order': 'Gentianales',
#   'name': 'Acrosynanthus latifolius Standl.',
#   'id': 990},
#  {'family': 'Rubiaceae',
#   'order': 'Gentianales',
#   'name': 'Acrosynanthus parvifolius Britton ex Standl.',
#   'id': 991},
#  {'family': 'Rubiaceae',
#   'order': 'Gentianales',
#   'name': 'Acrosynanthus revolutus Urb.',
#   'id': 992},
#  {'family': 'Ericaceae',
#   'order': 'Ericales',
#   'name': 'Acrothamnus colensoi (Hook.f.) Quinn',
#   'id': 993},
#  {'family': 'Ericaceae',
#   'order': 'Ericales',
#   'name': 'Acrothamnus suaveolens (Hook.f.) Quinn',
#   'id': 994},
#  {'family': 'Ericaceae',
#   'order': 'Ericales',
#   'name': 'Acrotriche baileyana (Domin) J.M.Powell',
#   'id': 995},
#  {'family': 'Cunoniaceae',
#   'order': 'Oxalidales',
#   'name': 'Acsmithia densiflora (Brongn. & Gris) Hoogland',
#   'id': 996},
#  {'family': 'Cunoniaceae',
#   'order': 'Oxalidales',
#   'name': 'Acsmithia integrifolia (Pulle) Hoogland',
#   'id': 997},
#  {'family': 'Cunoniaceae',
#   'order': 'Oxalidales',
#   'name': 'Acsmithia parvifolia (Schltr.) Hoogland',
#   'id': 998},
#  {'family': 'Cunoniaceae',
#   'order': 'Oxalidales',
#   'name': 'Acsmithia pulleana (Schltr.) Hoogland',
#   'id': 999},
#  ...]

# %%
categories = {cat['id']: cat for cat in train_metadata['categories']}
images = {im['id']: im for im in train_metadata['images']}
institutions = {inst['id']: inst for inst in train_metadata['institutions']}

# %%
train21_processed = [] # will be turned into a dataframe later. sublists are of the form <image_id>, <image_path>, <species>, <order>, <family>, <institution>

for i in range(len(train_metadata['annotations'])):
    image = train_metadata['annotations'][i]

    image_id = image['id']
    image_path = images[image_id]['file_name']
    category = categories[image['category_id']]
    institution = institutions[image['institution_id']]
    name = category['name']
    species = name.split(' ')[1]
    genus = name.split(' ')[0]
    family = category['family']

    sublist = [image_id, image_path, species, genus, family, institution['name']]
    train21_processed += [sublist]

# %%
df = pd.DataFrame(train21_processed, columns=['image_id', 'filename', 'species', 'genus', 'family', 'institution'])
df.head()
# Out:
#    image_id                   filename   species          genus        family  \
# 0   1814367  images/604/92/1814367.jpg  curvipes  Thysanocarpus  Brassicaceae
# 1   1308257  images/108/24/1308257.jpg   grandis         Cassia      Fabaceae
# 2   1270453  images/330/76/1270453.jpg    whitei   Leptospermum     Myrtaceae
# 3   1123834  images/247/99/1123834.jpg  scandens       Fallopia  Polygonaceae
# 4   1042410  images/170/18/1042410.jpg  dentatus        Cyperus    Cyperaceae
#
#                  institution
# 0  New York Botanical Garden
# 1  New York Botanical Garden
# 2       Queensland Herbarium
# 3  New York Botanical Garden
# 4  New York Botanical Garden

# %%
df.shape
# Out:
# (2257759, 6)

# %%
labeled = []
for i, row in df.iterrows():
    species = row['species']
    genus = row['genus']
    family = row['family']
    institution = row['institution']

    img_id = row['image_id']
    filename = row['filename'].replace("images/", "")
    caption = f"This is an image of species {species}, in the genus {genus} of family {family}. It is part of the collection of institution {institution}."
    scientificName = family + " " + genus + " " + species

    labeled += [[img_id, filename, caption, scientificName, family, genus, species]]

kaggle21 = pd.DataFrame(labeled, columns=["image_id", "filename", "caption", "scientificName", "family", "genus", "species"])

# %%
le = LabelEncoder()
le.fit(kaggle21['scientificName'])
kaggle21['scientificNameEncoded'] = le.transform(kaggle21['scientificName'])

train21, val21 = train_test_split(kaggle21, test_size=0.2, random_state=42)

# %%
train21.head()
# Out:
#          image_id            filename  \
# 1873445   1123740  494/80/1123740.jpg
# 644516    1242345  161/93/1242345.jpg
# 1177436   2238072  069/53/2238072.jpg
# 1700471      1458     001/99/1458.jpg
# 1958054    344538   219/79/344538.jpg
#
#                                                    caption  \
# 1873445  This is an image of species mollis, in the gen...
# 644516   This is an image of species parsonsia, in the ...
# 1177436  This is an image of species egensis, in the ge...
# 1700471  This is an image of species acradenia, in the ...
# 1958054  This is an image of species halleanum, in the ...
#
#                            scientificName           family      genus  \
# 1873445      Apocynaceae Prestonia mollis      Apocynaceae  Prestonia
# 644516        Lythraceae Cuphea parsonsia       Lythraceae     Cuphea
# 1177436  Melastomataceae Bellucia egensis  Melastomataceae   Bellucia
# 1700471         Fabaceae Acacia acradenia         Fabaceae     Acacia
# 1958054    Onagraceae Epilobium halleanum       Onagraceae  Epilobium
#
#            species  scientificNameEncoded
# 1873445     mollis                   3320
# 644516   parsonsia                  32636
# 1177436    egensis                  34222
# 1700471  acradenia                  22767
# 1958054  halleanum                  39755

# %%
val21.head()
# Out:
#          image_id            filename  \
# 720000    1926097  109/97/1926097.jpg
# 2107948     25793    426/57/25793.jpg
# 1715913    822223   532/16/822223.jpg
# 697108    1593343  359/14/1593343.jpg
# 1173726    531146   316/21/531146.jpg
#
#                                                    caption  \
# 720000   This is an image of species equisetifolia, in ...
# 2107948  This is an image of species hoffmannseggiana, ...
# 1715913  This is an image of species fragilis_x, in the...
# 697108   This is an image of species polyantha, in the ...
# 1173726  This is an image of species affinis, in the ge...
#
#                                 scientificName          family       genus  \
# 720000   Casuarinaceae Casuarina equisetifolia   Casuarinaceae   Casuarina
# 2107948  Rubiaceae Palicourea hoffmannseggiana       Rubiaceae  Palicourea
# 1715913            Salicaceae Salix fragilis_x      Salicaceae       Salix
# 697108     Marcgraviaceae Marcgravia polyantha  Marcgraviaceae  Marcgravia
# 1173726                Rubiaceae Kadua affinis       Rubiaceae       Kadua
#
#                   species  scientificNameEncoded
# 720000      equisetifolia                  13986
# 2107948  hoffmannseggiana                  54157
# 1715913        fragilis_x                  55603
# 697108          polyantha                  33963
# 1173726           affinis                  53838

# %%
train21.to_csv('/projectnb/herbdl/data/kaggle-herbaria/train_2021.csv')
val21.to_csv('/projectnb/herbdl/data/kaggle-herbaria/val_2021.csv')

# %%
train21.to_json('/projectnb/herbdl/data/kaggle-herbaria/train_2021.json', orient='records', lines=True)
val21.to_json('/projectnb/herbdl/data/kaggle-herbaria/val_2021.json', orient='records', lines=True)
